# %% [markdown]
# # 피처 그룹 Ablation 실험
# - **고정**: ID (sector + ticker OHE 126개)
# - **조합**: FIN / MKT / EMO / ECON → 15가지 조합
# - **FIN 버전**: vol3d / vol5d
# - **라벨 임계값**: ±0.5% / ±0.7% / ±1.0%
# - **모델**: HistGradientBoostingClassifier
# - **평가**: GroupKFold CV (날짜 기준 5fold) + Holdout 마지막 8거래일

# %%
import pandas as pd
import numpy as np
import itertools
import warnings
warnings.filterwarnings('ignore')

from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.model_selection import GroupKFold
from sklearn.metrics import f1_score

# %%
# ── 설정 ──────────────────────────────────────────────
HOLDOUT_DAYS = 8
N_SPLITS     = 5
DATA_DIR     = './'   # final_input 파일 위치

FIN_V1_COLS = [
    'return_1d','return_3d','return_5d','volatility_3d',
    'volume_change','volume_ma_ratio','sector_return_mean',
    'relative_return_to_sector','relative_return_to_market',
    'relative_volatility_to_sector_3d'
]
FIN_V2_COLS = [
    'return_1d','return_3d','return_5d','volatility_5d',
    'volume_change','volume_ma_ratio','sector_return_mean',
    'relative_return_to_sector','relative_return_to_market',
    'relative_volatility_to_sector_5d'
]
MKT_COLS = [
    'VIX_Close','VIX_return_1d','VIX_change_3d',
    'SPY_return_1d','SPY_return_3d','QQQ_return_3d',
    'Oil_return_1d','Gold_return_1d','Dollar_return_1d','Treasury10Y_return_1d'
]
LABEL_COLS = {
    '0.5%': 'label_05',
    '0.7%': 'label_07',
    '1.0%': 'label_10',
}

# %%
# ── 라벨 계산 (Close 가격 → 익일 수익률 방향) ──────────
raw = pd.read_csv(DATA_DIR + 'company_with_market_features.csv')
raw.columns = raw.columns.str.strip()
raw['Date'] = pd.to_datetime(raw['Date'])
raw = raw.sort_values(['ticker','Date']).reset_index(drop=True)
raw['next_return'] = raw.groupby('ticker')['Close'].pct_change(1).shift(-1)

for thr, name in [(0.005,'label_05'), (0.007,'label_07'), (0.01,'label_10')]:
    raw[name] = np.nan
    raw.loc[raw['next_return'] >  thr, name] = 2
    raw.loc[raw['next_return'] < -thr, name] = 0
    raw.loc[(raw['next_return'] >= -thr) & (raw['next_return'] <= thr), name] = 1

labels = raw[['Date','ticker','label_05','label_07','label_10']]

for col in ['label_05','label_07','label_10']:
    counts = labels[col].value_counts().sort_index()
    total  = counts.sum()
    print(f'{col}  down:{counts.get(0,0)}({counts.get(0,0)/total*100:.0f}%)  '
          f'neutral:{counts.get(1,0)}({counts.get(1,0)/total*100:.0f}%)  '
          f'up:{counts.get(2,0)}({counts.get(2,0)/total*100:.0f}%)  '
          f'NaN:{labels[col].isna().sum()}')
# Out:
# label_05  down:2014(39%)  neutral:1313(26%)  up:1790(35%)  NaN:119
# label_07  down:1770(35%)  neutral:1790(35%)  up:1557(30%)  NaN:119
# label_10  down:1440(28%)  neutral:2416(47%)  up:1261(25%)  NaN:119

# %%
def run_experiment(df, feat_cols, label_col):
    """GroupKFold CV + Holdout 평가. (cv_f1, holdout_f1, n_train, n_holdout) 반환"""
    sub = df[feat_cols + [label_col, 'Date']].dropna(subset=[label_col])
    sub = sub.dropna(subset=feat_cols, how='all')

    dates         = sorted(sub['Date'].unique())
    holdout_dates = dates[-HOLDOUT_DAYS:]
    train_dates   = dates[:-HOLDOUT_DAYS]

    train = sub[sub['Date'].isin(train_dates)].copy()
    hold  = sub[sub['Date'].isin(holdout_dates)].copy()

    X_tr = train[feat_cols].values
    y_tr = train[label_col].values.astype(int)
    X_ho = hold[feat_cols].values
    y_ho = hold[label_col].values.astype(int)

    date_to_idx = {d: i for i, d in enumerate(train_dates)}
    groups = train['Date'].map(date_to_idx).values

    model = HistGradientBoostingClassifier(
        learning_rate=0.05, max_depth=4,
        min_samples_leaf=20, class_weight='balanced',
        random_state=42
    )

    # CV
    gkf = GroupKFold(n_splits=N_SPLITS)
    cv_scores = []
    for tr_idx, val_idx in gkf.split(X_tr, y_tr, groups):
        model.fit(X_tr[tr_idx], y_tr[tr_idx])
        pred = model.predict(X_tr[val_idx])
        cv_scores.append(f1_score(y_tr[val_idx], pred, average='macro', zero_division=0))

    # Holdout
    model.fit(X_tr, y_tr)
    ho_pred = model.predict(X_ho)
    ho_f1   = f1_score(y_ho, ho_pred, average='macro', zero_division=0)

    return round(np.mean(cv_scores), 4), round(ho_f1, 4), len(train), len(hold)

# %%
# ── 전체 Ablation 실행 ────────────────────────────────
results = []
groups_map = ['FIN', 'MKT', 'EMO', 'ECON']

for vol_ver, fin_cols, fname in [
    ('vol3d', FIN_V1_COLS, 'final_input_vol3d.csv'),
    ('vol5d', FIN_V2_COLS, 'final_input_vol5d.csv'),
]:
    print(f'\n{"="*55}')
    print(f'FIN 버전: {vol_ver}')
    print(f'{"="*55}')

    df = pd.read_csv(DATA_DIR + fname, parse_dates=['Date'])

    # 라벨 merge
    df = pd.merge(df, labels, on=['Date','ticker'], how='left')

    emo_cols  = [c for c in df.columns if c.startswith('emo_')]
    econ_cols = [c for c in df.columns if c.startswith('reddit_')]
    id_cols   = [c for c in df.columns if c.startswith('sector_') or c.startswith('ticker_')]

    col_map = {
        'FIN' : fin_cols,
        'MKT' : MKT_COLS,
        'EMO' : emo_cols,
        'ECON': econ_cols,
    }

    for r in range(1, 5):
        for combo in itertools.combinations(groups_map, r):
            feat_cols  = id_cols.copy()
            for g in combo:
                feat_cols += col_map[g]
            combo_name = '+'.join(combo)

            for thr_name, label_col in LABEL_COLS.items():
                cv_f1, ho_f1, n_tr, n_ho = run_experiment(df, feat_cols, label_col)
                results.append({
                    'fin_ver'   : vol_ver,
                    'threshold' : thr_name,
                    'groups'    : combo_name,
                    'n_features': len(feat_cols),
                    'cv_f1'     : cv_f1,
                    'holdout_f1': ho_f1,
                    'n_train'   : n_tr,
                    'n_holdout' : n_ho,
                })
                print(f'[{vol_ver}] {thr_name} | ID+{combo_name:<22} | CV:{cv_f1:.3f}  Holdout:{ho_f1:.3f}')
# Out:
# =======================================================
# FIN 버전: vol3d
# =======================================================
# [vol3d] 0.5% | ID+FIN                    | CV:0.358  Holdout:0.390
# [vol3d] 0.7% | ID+FIN                    | CV:0.374  Holdout:0.407
# [vol3d] 1.0% | ID+FIN                    | CV:0.387  Holdout:0.388
# [vol3d] 0.5% | ID+MKT                    | CV:0.351  Holdout:0.385
# [vol3d] 0.7% | ID+MKT                    | CV:0.357  Holdout:0.410
# [vol3d] 1.0% | ID+MKT                    | CV:0.376  Holdout:0.410
# [vol3d] 0.5% | ID+EMO                    | CV:0.367  Holdout:0.330
# [vol3d] 0.7% | ID+EMO                    | CV:0.382  Holdout:0.355
# [vol3d] 1.0% | ID+EMO                    | CV:0.388  Holdout:0.386
# [vol3d] 0.5% | ID+ECON                   | CV:0.339  Holdout:0.360
# [vol3d] 0.7% | ID+ECON                   | CV:0.334  Holdout:0.362
# [vol3d] 1.0% | ID+ECON                   | CV:0.353  Holdout:0.403
# [vol3d] 0.5% | ID+FIN+MKT                | CV:0.360  Holdout:0.380
# [vol3d] 0.7% | ID+FIN+MKT                | CV:0.364  Holdout:0.417
# [vol3d] 1.0% | ID+FIN+MKT                | CV:0.382  Holdout:0.421
# [vol3d] 0.5% | ID+FIN+EMO                | CV:0.366  Holdout:0.365
# [vol3d] 0.7% | ID+FIN+EMO                | CV:0.374  Holdout:0.365
# [vol3d] 1.0% | ID+FIN+EMO                | CV:0.394  Holdout:0.401
# [vol3d] 0.5% | ID+FIN+ECON               | CV:0.354  Holdout:0.382
# [vol3d] 0.7% | ID+FIN+ECON               | CV:0.342  Holdout:0.381
# [vol3d] 1.0% | ID+FIN+ECON               | CV:0.347  Holdout:0.404
# [vol3d] 0.5% | ID+MKT+EMO                | CV:0.355  Holdout:0.403
# [vol3d] 0.7% | ID+MKT+EMO                | CV:0.359  Holdout:0.404
# [vol3d] 1.0% | ID+MKT+EMO                | CV:0.368  Holdout:0.418
# [vol3d] 0.5% | ID+MKT+ECON               | CV:0.327  Holdout:0.345
# [vol3d] 0.7% | ID+MKT+ECON               | CV:0.344  Holdout:0.404
# [vol3d] 1.0% | ID+MKT+ECON               | CV:0.343  Holdout:0.399
# [vol3d] 0.5% | ID+EMO+ECON               | CV:0.365  Holdout:0.333
# [vol3d] 0.7% | ID+EMO+ECON               | CV:0.363  Holdout:0.367
# [vol3d] 1.0% | ID+EMO+ECON               | CV:0.383  Holdout:0.433
# [vol3d] 0.5% | ID+FIN+MKT+EMO            | CV:0.364  Holdout:0.398
# [vol3d] 0.7% | ID+FIN+MKT+EMO            | CV:0.357  Holdout:0.438
# [vol3d] 1.0% | ID+FIN+MKT+EMO            | CV:0.378  Holdout:0.414
# [vol3d] 0.5% | ID+FIN+MKT+ECON           | CV:0.322  Holdout:0.356
# [vol3d] 0.7% | ID+FIN+MKT+ECON           | CV:0.334  Holdout:0.414
# [vol3d] 1.0% | ID+FIN+MKT+ECON           | CV:0.357  Holdout:0.407
# [vol3d] 0.5% | ID+FIN+EMO+ECON           | CV:0.351  Holdout:0.356
# [vol3d] 0.7% | ID+FIN+EMO+ECON           | CV:0.368  Holdout:0.368
# [vol3d] 1.0% | ID+FIN+EMO+ECON           | CV:0.372  Holdout:0.413
# [vol3d] 0.5% | ID+MKT+EMO+ECON           | CV:0.355  Holdout:0.396
# [vol3d] 0.7% | ID+MKT+EMO+ECON           | CV:0.370  Holdout:0.405
# [vol3d] 1.0% | ID+MKT+EMO+ECON           | CV:0.364  Holdout:0.420
# [vol3d] 0.5% | ID+FIN+MKT+EMO+ECON       | CV:0.356  Holdout:0.397
# [vol3d] 0.7% | ID+FIN+MKT+EMO+ECON       | CV:0.356  Holdout:0.407
# [vol3d] 1.0% | ID+FIN+MKT+EMO+ECON       | CV:0.367  Holdout:0.418
#
# =======================================================
# FIN 버전: vol5d
# =======================================================
# [vol5d] 0.5% | ID+FIN                    | CV:0.355  Holdout:0.395
# [vol5d] 0.7% | ID+FIN                    | CV:0.373  Holdout:0.414
# [vol5d] 1.0% | ID+FIN                    | CV:0.378  Holdout:0.402
# [vol5d] 0.5% | ID+MKT                    | CV:0.351  Holdout:0.385
# [vol5d] 0.7% | ID+MKT                    | CV:0.357  Holdout:0.410
# [vol5d] 1.0% | ID+MKT                    | CV:0.376  Holdout:0.410
# [vol5d] 0.5% | ID+EMO                    | CV:0.367  Holdout:0.330
# [vol5d] 0.7% | ID+EMO                    | CV:0.382  Holdout:0.355
# [vol5d] 1.0% | ID+EMO                    | CV:0.388  Holdout:0.386
# [vol5d] 0.5% | ID+ECON                   | CV:0.339  Holdout:0.360
# [vol5d] 0.7% | ID+ECON                   | CV:0.334  Holdout:0.362
# [vol5d] 1.0% | ID+ECON                   | CV:0.353  Holdout:0.403
# [vol5d] 0.5% | ID+FIN+MKT                | CV:0.348  Holdout:0.379
# [vol5d] 0.7% | ID+FIN+MKT                | CV:0.376  Holdout:0.417
# [vol5d] 1.0% | ID+FIN+MKT                | CV:0.384  Holdout:0.427
# [vol5d] 0.5% | ID+FIN+EMO                | CV:0.361  Holdout:0.354
# [vol5d] 0.7% | ID+FIN+EMO                | CV:0.376  Holdout:0.349
# [vol5d] 1.0% | ID+FIN+EMO                | CV:0.381  Holdout:0.386
# [vol5d] 0.5% | ID+FIN+ECON               | CV:0.355  Holdout:0.384
# [vol5d] 0.7% | ID+FIN+ECON               | CV:0.348  Holdout:0.379
# [vol5d] 1.0% | ID+FIN+ECON               | CV:0.351  Holdout:0.408
# [vol5d] 0.5% | ID+MKT+EMO                | CV:0.355  Holdout:0.403
# [vol5d] 0.7% | ID+MKT+EMO                | CV:0.359  Holdout:0.404
# [vol5d] 1.0% | ID+MKT+EMO                | CV:0.368  Holdout:0.418
# [vol5d] 0.5% | ID+MKT+ECON               | CV:0.327  Holdout:0.345
# [vol5d] 0.7% | ID+MKT+ECON               | CV:0.344  Holdout:0.404
# [vol5d] 1.0% | ID+MKT+ECON               | CV:0.343  Holdout:0.399
# [vol5d] 0.5% | ID+EMO+ECON               | CV:0.365  Holdout:0.333
# [vol5d] 0.7% | ID+EMO+ECON               | CV:0.363  Holdout:0.367
# [vol5d] 1.0% | ID+EMO+ECON               | CV:0.383  Holdout:0.433
# [vol5d] 0.5% | ID+FIN+MKT+EMO            | CV:0.357  Holdout:0.426
# [vol5d] 0.7% | ID+FIN+MKT+EMO            | CV:0.384  Holdout:0.402
# [vol5d] 1.0% | ID+FIN+MKT+EMO            | CV:0.383  Holdout:0.414
# [vol5d] 0.5% | ID+FIN+MKT+ECON           | CV:0.321  Holdout:0.377
# [vol5d] 0.7% | ID+FIN+MKT+ECON           | CV:0.351  Holdout:0.401
# [vol5d] 1.0% | ID+FIN+MKT+ECON           | CV:0.348  Holdout:0.428
# [vol5d] 0.5% | ID+FIN+EMO+ECON           | CV:0.356  Holdout:0.342
# [vol5d] 0.7% | ID+FIN+EMO+ECON           | CV:0.354  Holdout:0.377
# [vol5d] 1.0% | ID+FIN+EMO+ECON           | CV:0.366  Holdout:0.386
# [vol5d] 0.5% | ID+MKT+EMO+ECON           | CV:0.355  Holdout:0.396
# [vol5d] 0.7% | ID+MKT+EMO+ECON           | CV:0.370  Holdout:0.405
# [vol5d] 1.0% | ID+MKT+EMO+ECON           | CV:0.364  Holdout:0.420
# [vol5d] 0.5% | ID+FIN+MKT+EMO+ECON       | CV:0.371  Holdout:0.426
# [vol5d] 0.7% | ID+FIN+MKT+EMO+ECON       | CV:0.367  Holdout:0.411
# [vol5d] 1.0% | ID+FIN+MKT+EMO+ECON       | CV:0.357  Holdout:0.414

# %%
# ── 결과 저장 ─────────────────────────────────────────
result_df = pd.DataFrame(results)
result_df = result_df.sort_values(['fin_ver','threshold','holdout_f1'], ascending=[True,True,False])
result_df.to_csv(DATA_DIR + 'ablation_results.csv', index=False)
print('→ ablation_results.csv 저장 완료')
# Out:
# → ablation_results.csv 저장 완료

# %%
# ── 요약: 임계값별 Holdout Top 5 ─────────────────────
for thr in ['0.5%', '0.7%', '1.0%']:
    sub = result_df[result_df['threshold'] == thr]
    print(f'\n★ [{thr}] Holdout F1 Top 5')
    print(sub.nlargest(5, 'holdout_f1')[['fin_ver','groups','cv_f1','holdout_f1']].to_string(index=False))
# Out:
# ★ [0.5%] Holdout F1 Top 5
# fin_ver           groups  cv_f1  holdout_f1
#   vol5d FIN+MKT+EMO+ECON 0.3706      0.4262
#   vol5d      FIN+MKT+EMO 0.3571      0.4260
#   vol3d          MKT+EMO 0.3555      0.4026
#   vol5d          MKT+EMO 0.3555      0.4026
#   vol3d      FIN+MKT+EMO 0.3638      0.3980
#
# ★ [0.7%] Holdout F1 Top 5
# fin_ver       groups  cv_f1  holdout_f1
#   vol3d  FIN+MKT+EMO 0.3573      0.4380
#   vol3d      FIN+MKT 0.3642      0.4170
#   vol5d      FIN+MKT 0.3764      0.4167
#   vol3d FIN+MKT+ECON 0.3335      0.4142
#   vol5d          FIN 0.3732      0.4139
#
# ★ [1.0%] Holdout F1 Top 5
# fin_ver       groups  cv_f1  holdout_f1
#   vol3d     EMO+ECON 0.3827      0.4327
#   vol5d     EMO+ECON 0.3827      0.4327
#   vol5d FIN+MKT+ECON 0.3477      0.4283
#   vol5d      FIN+MKT 0.3839      0.4274
#   vol3d      FIN+MKT 0.3821      0.4213

# %%
# ── 피벗 테이블: 한눈에 보기 (임계값 선택) ───────────
TARGET_THR = '0.7%'   # ← 0.5% / 0.7% / 1.0% 중 선택

pivot = result_df[result_df['threshold'] == TARGET_THR].pivot_table(
    index='groups', columns='fin_ver',
    values='holdout_f1'
).round(3)

pivot = pivot.sort_values('vol3d', ascending=False)
print(f'[{TARGET_THR}] Holdout F1 — 피처 조합 × FIN버전')
print(pivot.to_string())
# Out:
# [0.7%] Holdout F1 — 피처 조합 × FIN버전
# fin_ver           vol3d  vol5d
# groups
# FIN+MKT+EMO       0.438  0.402
# FIN+MKT           0.417  0.417
# FIN+MKT+ECON      0.414  0.401
# MKT               0.410  0.410
# FIN               0.407  0.414
# FIN+MKT+EMO+ECON  0.407  0.411
# MKT+EMO+ECON      0.405  0.405
# MKT+ECON          0.404  0.404
# MKT+EMO           0.404  0.404
# FIN+ECON          0.381  0.379
# EMO+ECON          0.368  0.368
# FIN+EMO+ECON      0.368  0.376
# FIN+EMO           0.365  0.349
# ECON              0.362  0.362
# EMO               0.355  0.355
